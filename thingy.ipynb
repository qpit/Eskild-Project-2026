# %%
import numpy as np

# %%
c = 3*10**8
lamb = 1550*10**-9
d = 15*10**(-12)
epsilon_0 = 8.854*10**-12
L = 10*10**-3 

n1 = 1.81
n2 = 1.85
h = 1.5
input_power = 36*10**(-3)
power_expected = 16*np.pi**2*d**2*L /(epsilon_0*n1*n2*lamb**3*c) *input_power**2 * h
print(power_expected*1e6)
# Out:
# 20.85414248920196
